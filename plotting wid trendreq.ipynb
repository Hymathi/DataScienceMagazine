# %%
import pandas as pd
#Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for
#multi-dimensional arrays
from pytrends.request import TrendReq
#What is Pytrends? Pytrends is an unofficial Google Trends API for Python. It allows us to extract data of all kinds related to the interest of users in a specific topic or query.
import matplotlib.pyplot as plt
#Matplotlib is a python library used to create 2D graphs and plots by using python scripts. It has a module named pyplot which makes things easy for plotting by providing feature to control line styles,
#font properties, formatting axes etc.
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Data Science"])
#The build_payload method from Pytrends is used to build a list of keywords you want to search in Google Trends. You can also specify
#the timeframe to gather data and the category to query the data from. For this example, we will search trends for the “machine learning” keyword.
data = trends.interest_by_region()

data = data.sort_values(by="Data Science", ascending=False)
data = data.head(10)
print(data)
# Out:
#            Data Science
# geoName
# Ethiopia            100
# India               100
# Singapore           100
# China                98
# Nigeria              85
# Kenya                75
# Pakistan             68
# Ghana                67
# Nepal                66
# Sri Lanka            53

# %%
import pandas as pd
#Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for
#multi-dimensional arrays
from pytrends.request import TrendReq
#What is Pytrends? Pytrends is an unofficial Google Trends API for Python. It allows us to extract data of all kinds related to the interest of users in a specific topic or query.
import matplotlib.pyplot as plt
#Matplotlib is a python library used to create 2D graphs and plots by using python scripts. It has a module named pyplot which makes things easy for plotting by providing feature to control line styles,
#font properties, formatting axes etc.
trends = TrendReq()

trends.build_payload(kw_list=["Data Science"])
#The build_payload method from Pytrends is used to build a list of keywords you want to search in Google Trends. You can also specify
#the timeframe to gather data and the category to query the data from. For this example, we will search trends for the “machine learning” keyword.
data = trends.interest_by_region()

data = data.sort_values(by="Data Science", ascending=False)
data = data.head(10)
print(data)

data.reset_index().plot(x="geoName", y="Data Science",
                        figsize=(20,15), kind="bar",color='red')
plt.style.use('fivethirtyeight')# one of the style.
plt.show()

data=TrendReq(hl='en-US',tz=360)
data.build_payload(kw_list=['Death rate'],timeframe=['2015-09-04 2023-09-10', '2015-09-18 2023-09-24'])
data=data.interest_over_time()
fig, ax= plt.subplots(figsize=(20,15))
data['Death rate'].plot()
plt.style.use=('fivethirtyeight')
plt.title('Total Google Searches for deathrate')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
# Out:
#            Data Science
# geoName
# India               100
# Singapore            98
# Ethiopia             98
# China                97
# Nigeria              82
# Kenya                76
# Pakistan             68
# Ghana                68
# Nepal                64
# Sri Lanka            52
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-f883b2363a8e> in <module>
#      20 data.reset_index().plot(x="geoName", y="Data Science",
#      21                         figsize=(20,15), kind="bar",color='red')
# ---> 22 plt.style.use('fivethirtyeight')# one of the style.
#      23 plt.show()
#      24
#
# TypeError: 'str' object is not callable

# %%
data=TrendReq(hl='en-US',tz=360)
data.build_payload(kw_list=['remote job'],timeframe=['2019-09-04 2022-09-10', '2022-09-18 2022-09-24'])
data=data.interest_over_time()
fig, ax= plt.subplots(figsize=(20,15))
data['dairy milk'].plot()
plt.style.use=('fivethirtyeight')
plt.title('Total Google Searches for dairy milk')
plt.xlabel('Year')
plt.ylabel
plt.show()

# %%
data=TrendReq(hl='en-US',tz=360)
data.build_payload(kw_list=['netflix'],timeframe=['2018-09-04 2023-09-10', '2018-09-18 2023-09-24'])
data=data.interest_over_time()
fig, ax= plt.subplots(figsize=(20,15))
data['netflix'].plot()
plt.style.use=('fivethirtyeight')
plt.title('Total Google Searches netflix')
plt.xlabel('Year')
plt.ylabel
plt.show()

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
